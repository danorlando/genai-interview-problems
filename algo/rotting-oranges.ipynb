# %% [markdown]
# # Algorithm Problem 005: Rotting Oranges
#
# ## Difficulty: Medium
#
# ## Problem Description
#
# You are given an `m x n` grid where each cell can have one of three values:
#
# - `0` representing an empty cell
# - `1` representing a fresh orange
# - `2` representing a rotten orange
#
# Every minute, any fresh orange that is **4-directionally adjacent** to a rotten orange becomes rotten.
#
# Return the **minimum number of minutes** that must elapse until no cell has a fresh orange. If this is impossible, return `-1`.
#
# ## Examples
#
# ```python
# Example 1:
# Input: grid = [[2,1,1],[1,1,0],[0,1,1]]
# Output: 4
# Explanation:
# Minute 0: [[2,1,1],
#            [1,1,0],
#            [0,1,1]]
# Minute 1: [[2,2,1],
#            [2,1,0],
#            [0,1,1]]
# Minute 2: [[2,2,2],
#            [2,2,0],
#            [0,1,1]]
# Minute 3: [[2,2,2],
#            [2,2,0],
#            [0,2,1]]
# Minute 4: [[2,2,2],
#            [2,2,0],
#            [0,2,2]]
#
# Example 2:
# Input: grid = [[2,1,1],[0,1,1],[1,0,1]]
# Output: -1
# Explanation: The orange in the bottom left corner (row 2, column 0) is never rotten,
# because rotting only happens 4-directionally.
#
# Example 3:
# Input: grid = [[0,2]]
# Output: 0
# Explanation: Since there are already no fresh oranges at minute 0, the answer is 0.
# ```
#
# ## Constraints
#
# - `m == grid.length`
# - `n == grid[i].length`
# - `1 <= m, n <= 10`
# - `grid[i][j]` is `0`, `1`, or `2`
#
# ## GenAI Context
#
# This problem mirrors propagation patterns in distributed systems, like how updated embeddings spread through a vector database cluster, or how model updates propagate in federated learning.
#
# ## Hints
#
# <details>
# <summary>Hint 1</summary>
# This is a multi-source BFS problem. All rotten oranges rot their neighbors simultaneously each minute.
# </details>
#
# <details>
# <summary>Hint 2</summary>
# Start BFS from all initially rotten oranges at once. Use a queue and track the time/level.
# </details>
#
# <details>
# <summary>Hint 3</summary>
# Count the fresh oranges at the start. If any remain fresh after BFS completes, return -1.
# </details>

# %% [markdown]
# # 🎯 PROBLEM DECOMPOSITION (Complete Before Looking at Hints!)
#
# **Purpose**: Build explicit understanding of what data matters BEFORE implementation
#
# ---
#
# ## Section 1: Input Analysis
# **What data do we have?**
# - Type: m × n grid
# - Size constraints: 1 ≤ m, n ≤ 10
# - What each value represents: 0 (empty), 1 (fresh), 2 (rotten)
#
# **Questions to answer:**
# - How is the rotten/fresh state represented? - by 0, 1, or 2
# - What information is stored in the grid cells? - if there is an orange and its state
# - Are there any "dummy" cells or padding? - 0 is a dummy cell because it is empty
#
# *Write your answers below:*
# ```
# The state of an orange is represented by being either 1 - fresh, or 2 - rotten.
# The cell stores whether the
# ```
#
# ---
#
# ## Section 2: Output Analysis
# **What are we computing?**
# - Return type: integer (minutes)
# - What should we return when all oranges are already rotten?
# - What should we return when some oranges can never rot?
#
# **Questions to answer:**
# - Are we computing minimum TIME or minimum STEPS?
# - What's the difference?
# - What happens if there are no fresh oranges initially?
#
# *Write your answers below:*
# ```
# [Your analysis here]
# ```
#
# ---
#
# ## Section 3: Relevance Analysis - "What Data Matters?" ⭐
# **This is the CRITICAL section. Which data is RELEVANT to solving this problem?**
#
# **RELEVANT Data (Track this):**
# - [ ] Initial positions of rotten oranges?
# - [ ] Initial positions of fresh oranges?
# - [ ] Time elapsed?
# - [ ] How many fresh oranges remain?
# - [ ] The exact coordinates we visit?
#
# **NOT RELEVANT Data (Ignore this):**
# - [ ] [What doesn't matter?]
#
# **Decision Points:**
# 1. Do we need to know the EXACT state of the grid at each minute, or just the COUNT of fresh oranges?
# 2. Do we need to remember which specific oranges we visited, or just track if they're fresh/rotten?
# 3. When an orange rots, do we care WHICH orange it was, or just that SOME orange became rotten?
#
# **⭐ Critical Insight**: Compare this to ALGO-003 (Task Scheduler). In that problem, did we care about the task IDENTITY or the task FREQUENCY? What's different here?
#
# *Write your answers below:*
# ```
# [Your analysis here]
# ```
#
# ---
#
# ## Section 4: Algorithm Pattern - Data Flow
# **How does data transform through the algorithm?**
#
# **Input Stage:**
# - Parse the grid to identify:
#   - Where are the initial rotten oranges?
#   - How many fresh oranges are there total?
#   - What else is important?
#
# **Processing Stage:**
# - What happens each minute?
# - How do we simulate the rotting propagation?
# - How do we track time?
# - How do we know when we're done?
#
# **Output Stage:**
# - After processing, how do we determine what to return?
# - What conditions lead to returning each possible result?
#
# **Data Flow Diagram (simple):**
# ```
# Input: grid
#   ↓
# Step 1: [what happens here?]
#   ↓
# Step 2: [what happens here?]
#   ↓
# Step 3: [what happens here?]
#   ↓
# Output: minutes
# ```
#
# *Write your answers below:*
# ```
# [Your analysis here]
# ```
#
# ---
#
# ## Section 5: Key Algorithm Questions
# Before looking at hints, try to answer these:
#
# 1. **Multiple Starting Points**: What makes this different from a regular BFS starting from one point?
#    - How do we handle multiple rotten oranges at the start?
#
# 2. **Simultaneous Propagation**: In reality, all rotten oranges rot their neighbors AT THE SAME TIME each minute.
#    - How do we simulate this with BFS?
#    - Why can't we just process one rotten orange at a time?
#
# 3. **Level Tracking (Building on recent learning)**:
#    - Remember ALGO-002 Word Ladder? This also needs level tracking.
#    - How will you track which minute each orange becomes rotten?
#
# 4. **Impossible Case**:
#    - How will you detect when it's impossible to rot all oranges?
#    - What's the SIMPLEST way to check this?
#
# *Write your answers below:*
# ```
# [Your analysis here]
# ```
#
# ---
#
# ## Section 6: Implementation Plan (No Code Yet!)
# Based on your analysis above, outline the steps WITHOUT writing code:
#
# 1. Initialize: [what setup do we need?]
# 2. While: [what's the loop condition?]
# 3. Each iteration: [what happens?]
# 4. Return: [what do we return and when?]
#
# *Write your outline below:*
# ```
# [Your analysis here]
# ```
#
# ---
#
# **⚠️ Only after completing all sections above should you look at Hints!**

# %% [markdown]
# ## Your Solution
#
# Write your solution below:

# %%
from typing import List

def oranges_rotting(grid: List[List[int]]) -> int:
    """
    Calculate minimum minutes for all oranges to rot.
    
    Args:
        grid: m x n grid with 0 (empty), 1 (fresh), 2 (rotten)
        
    Returns:
        Minimum minutes needed, or -1 if impossible
    """
    # Your code here
    pass

# %% [markdown]
# ## Test Cases
#
# Run these test cases to verify your solution:

# %%
# Test Case 1
assert oranges_rotting([[2,1,1],[1,1,0],[0,1,1]]) == 4
print("✅ Test 1 passed")

# Test Case 2
assert oranges_rotting([[2,1,1],[0,1,1],[1,0,1]]) == -1
print("✅ Test 2 passed")

# Test Case 3
assert oranges_rotting([[0,2]]) == 0
print("✅ Test 3 passed")

# Test Case 4: All fresh, no rotten
assert oranges_rotting([[1,1,1],[1,1,1]]) == -1
print("✅ Test 4 passed")

# Test Case 5: All rotten or empty
assert oranges_rotting([[2,2,0],[0,2,2]]) == 0
print("✅ Test 5 passed")

# Test Case 6: Single rotten orange spreads
assert oranges_rotting([[2,1],[1,1]]) == 2
print("✅ Test 6 passed")

# Test Case 7: Empty grid
assert oranges_rotting([[0,0],[0,0]]) == 0
print("✅ Test 7 passed")

print("\n🎉 All test cases passed!")

# %% [markdown]
# ## Complexity Analysis
#
# After implementing your solution, analyze its complexity:
#
# **Time Complexity:**
# - Your analysis here
#
# **Space Complexity:**
# - Your analysis here
#
# **Explanation:**
# - Explain your approach and why it achieves this complexity
